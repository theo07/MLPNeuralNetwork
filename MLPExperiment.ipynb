# %%
from __future__ import print_function
from dataPreprocessing import Items
import tensorflow as tf
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn import svm
from sklearn.naive_bayes import GaussianNB
from astropy.table import Table
import math 

#own data preprocessing from Mondaq database
#author data of articles
#will predict who is an author or not
#a simple but powerful experiment
my_items = Items([],[])
my_items.createData()

train_items, test_items = my_items.splitTrainTest()

# Parameters
learning_rate = 0.009
training_epochs = 1200
batch_size = 100
display_step = 1
logs_path = '/tmp/tensorflow_logs/example'
beta = 0.005
# Network Parameters
n_hidden_1 = 35 # 1st layer number of features
n_hidden_2 = 25 # 2nd layer number of features
n_input = 10 # author data input 
n_classes = 2 # author classes 0 - no ; 1 - yes

# tf Graph input
x = tf.placeholder("float", [None, n_input])
y = tf.placeholder("float", [None, n_classes])

#model inspired by this tutorial
#https://github.com/aymericdamien/TensorFlow-Examples/blob/master/notebooks/3_NeuralNetworks/multilayer_perceptron.ipynb
#but the tutorial is generic and found that most of them are similar

# Create model
def multilayer_perceptron(x, weights, biases):
    # Hidden layer with RELU activation
    layer_1 = tf.add(tf.matmul(x, weights['h1']), biases['b1'])
    layer_1 = tf.nn.relu(layer_1)
    # Hidden layer 2 with RELU activation
    layer_2 = tf.add(tf.matmul(layer_1, weights['h2']), biases['b2'])
    layer_2 = tf.nn.relu(layer_2)
    ## Output layer with linear activation
    out_layer = tf.matmul(layer_2, weights['out']) + biases['out']
    return out_layer

# Store layers weight & bias
weights = {
    'h1': tf.Variable(tf.random_uniform([n_input, n_hidden_1], minval=-math.sqrt(6/5), maxval= math.sqrt(6/5))),
    'h2': tf.Variable(tf.random_uniform([n_hidden_1, n_hidden_2], minval=-math.sqrt(6/6), maxval= math.sqrt(6/6))),
    'out': tf.Variable(tf.random_uniform([n_hidden_2, n_classes], minval=-math.sqrt(6/7), maxval= math.sqrt(6/7)))
}
biases = {
    'b1': tf.Variable(tf.random_uniform([n_hidden_1], minval=-math.sqrt(6/5), maxval= math.sqrt(6/5))),
    'b2': tf.Variable(tf.random_uniform([n_hidden_2], minval=-math.sqrt(6/5), maxval= math.sqrt(6/5))),
    'out': tf.Variable(tf.random_uniform([n_classes], minval=-math.sqrt(6/5), maxval= math.sqrt(6/5)))
}

# Construct model and encapsulating all ops into scopes, making
# Tensorboard's Graph visualization more convenient
with tf.name_scope('Model'):
    # Model
    pred = multilayer_perceptron(x, weights, biases)
with tf.name_scope('Loss'):
    # Minimize error using cross entropy
    cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y)
                         + beta*tf.nn.l2_loss(weights['out']))
with tf.name_scope('Adam'):
    # Gradient Descent
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Create a summary to monitor cost tensor
tf.summary.scalar("loss", cost)

# Merge all summaries into a single op
merged_summary_op = tf.summary.merge_all()

# Initializing the variables
init = tf.global_variables_initializer()

# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    # op to write logs to Tensorboard
    summary_writer = tf.summary.FileWriter(logs_path, graph=tf.get_default_graph())

    # Training cycle
    for epoch in range(training_epochs):
        avg_cost = 0.
        total_batch = int(len(train_items.data)/batch_size)
        # Loop over all batches
        for i in range(total_batch):
            batch_x, batch_y = train_items.next(batch_size)
            # Run optimization op (backprop) and cost op (to get loss value)
            _, c, summary = sess.run([optimizer, cost, merged_summary_op], feed_dict={x: batch_x, y: batch_y})
                       # Write logs at every iteration
            summary_writer.add_summary(summary, epoch * total_batch + i)                                              
            # Compute average loss
            avg_cost += c / total_batch
        # Display logs per epoch step
        if epoch % display_step == 0:
            print("Epoch:", '%04d' % (epoch+1), "cost=", \
                "{:.9f}".format(avg_cost))
    print("Optimization Finished!")

    # Test model
    correct_prediction = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
    # Calculate accuracy
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))
    print("Accuracy:", accuracy.eval({x: test_items.data, y: test_items.labels}))

def calculate_stats(labels_data):
    one_label = 0
    for label in labels_data:
        if label == 1:
            one_label += 1
    zero_label = len(labels_data) - one_label
    one_label_percentage = one_label * 100 / (one_label + zero_label)
    return one_label_percentage

def one_hot_decode(y_data):
    y_decode_data = []
    for el in y_data:
        if el[0] == 1:
            y_decode_data.append(1)
        else:
            y_decode_data.append(0)
    return y_decode_data

#creating astropy tables for machine learning comparison
a4 = ['KNN-20','SVM','GaussianNB']
b4 = []

a3 = ['Train', 'Test', 'Total']
b3 = []
c3 = []

train_labels = one_hot_decode(train_items.labels)
test_labels = one_hot_decode(test_items.labels)

train_labels_one_percentage = calculate_stats(train_labels)
test_labels_one_percentage = calculate_stats(test_labels)

total_labels = []
total_labels.extend(train_labels)
total_labels.extend(test_labels)
total_labels_one_percentage = calculate_stats(total_labels)

b3.append(train_labels_one_percentage)
b3.append(test_labels_one_percentage)
b3.append(total_labels_one_percentage)
c3.append(100-train_labels_one_percentage)
c3.append(100-test_labels_one_percentage)
c3.append(100-total_labels_one_percentage)

t3 = Table([a3, b3, c3], names=('Labels Sample', 'Label-1-Percentage', 'Label-0-Percentage'), meta={'name': 'first table'})
print('')
print('Data Binary Label Statistics')
print('')
print(t3)

neigh = KNeighborsClassifier(n_neighbors=20)
neigh.fit(train_items.data, train_labels)

y_pred = neigh.predict(test_items.data)
b4.append(accuracy_score(test_labels, y_pred))

clf = svm.SVC()
clf.fit(train_items.data, train_labels)
y_pred2 = clf.predict(test_items.data)


b4.append(accuracy_score(test_labels, y_pred2))

gnb = GaussianNB()
y_pred3 = gnb.fit(train_items.data, train_labels).predict(test_items.data)
b4.append(accuracy_score(test_labels, y_pred3))

t4 = Table([a4,b4], names=('ML Algorithm', 'Prediction Accuracy'), meta={'name': 'second table'})
print('Evaluating the model for 3 ML Algorithms')
print('')
print(t4)
# Out:
# Please enter the file path of the authorData.csv provided: /home/teo/Desktop/Untitled Folder/experimentAuthor
# Cannot open file | File I|O Error | Try Again | Error as  Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.
# Please enter the file path of the authorData.csv provided: /home/teo/Desktop/Untitled Folder/experimentAuthor/authorData.csv
# Total number of the population:  77186
# Total training number of entries:  46311
# Epoch: 0001 cost= 0.081312190
# Epoch no:  1
# Epoch: 0002 cost= 0.044684742
# Epoch no:  2
# Epoch: 0003 cost= 0.038809388
# Epoch no:  3
# Epoch: 0004 cost= 0.036565254
# Epoch no:  4
# Epoch: 0005 cost= 0.035433033
# Epoch no:  5
# Epoch: 0006 cost= 0.034882529
# Epoch no:  6
# Epoch: 0007 cost= 0.034418351
# Epoch no:  7
# Epoch: 0008 cost= 0.034273084
# Epoch no:  8
# Epoch: 0009 cost= 0.034204302
# Epoch no:  9
# Epoch: 0010 cost= 0.033553952
# Epoch no:  10
# Epoch: 0011 cost= 0.033758136
# Epoch no:  11
# Epoch: 0012 cost= 0.033615025
# Epoch no:  12
# Epoch: 0013 cost= 0.033483174
# Epoch no:  13
# Epoch: 0014 cost= 0.033289989
# Epoch no:  14
# Epoch: 0015 cost= 0.033208190
# Epoch no:  15
# Epoch: 0016 cost= 0.033054459
# Epoch no:  16
# Epoch: 0017 cost= 0.033007220
# Epoch no:  17
# Epoch: 0018 cost= 0.032897617
# Epoch no:  18
# Epoch: 0019 cost= 0.032689907
# Epoch no:  19
# Epoch: 0020 cost= 0.032581418
# Epoch no:  20
# Epoch: 0021 cost= 0.032566843
# Epoch no:  21
# Epoch: 0022 cost= 0.032492363
# Epoch no:  22
# Epoch: 0023 cost= 0.032338501
# Epoch no:  23
# Epoch: 0024 cost= 0.032440171
# Epoch no:  24
# Epoch: 0025 cost= 0.032192802
# Epoch no:  25
# Epoch: 0026 cost= 0.032220315
# Epoch no:  26
# Epoch: 0027 cost= 0.032172580
# Epoch no:  27
# Epoch: 0028 cost= 0.032010587
# Epoch no:  28
# Epoch: 0029 cost= 0.031916589
# Epoch no:  29
# Epoch: 0030 cost= 0.031902046
# Epoch no:  30
# Epoch: 0031 cost= 0.032124057
# Epoch no:  31
# Epoch: 0032 cost= 0.032212162
# Epoch no:  32
# Epoch: 0033 cost= 0.031882144
# Epoch no:  33
# Epoch: 0034 cost= 0.031737285
# Epoch no:  34
# Epoch: 0035 cost= 0.031636044
# Epoch no:  35
# Epoch: 0036 cost= 0.031488176
# Epoch no:  36
# Epoch: 0037 cost= 0.031553758
# Epoch no:  37
# Epoch: 0038 cost= 0.031445397
# Epoch no:  38
# Epoch: 0039 cost= 0.031512504
# Epoch no:  39
# Epoch: 0040 cost= 0.031474281
# Epoch no:  40
# Epoch: 0041 cost= 0.031501690
# Epoch no:  41
# Epoch: 0042 cost= 0.031271963
# Epoch no:  42
# Epoch: 0043 cost= 0.031265945
# Epoch no:  43
# Epoch: 0044 cost= 0.031247487
# Epoch no:  44
# Epoch: 0045 cost= 0.031269244
# Epoch no:  45
# Epoch: 0046 cost= 0.031352910
# Epoch no:  46
# Epoch: 0047 cost= 0.031123321
# Epoch no:  47
# Epoch: 0048 cost= 0.031137420
# Epoch no:  48
# Epoch: 0049 cost= 0.031104012
# Epoch no:  49
# Epoch: 0050 cost= 0.030958287
# Epoch no:  50
# Epoch: 0051 cost= 0.031044071
# Epoch no:  51
# Epoch: 0052 cost= 0.030979750
# Epoch no:  52
# Epoch: 0053 cost= 0.030972938
# Epoch no:  53
# Epoch: 0054 cost= 0.030880185
# Epoch no:  54
# Epoch: 0055 cost= 0.030963722
# Epoch no:  55
# Epoch: 0056 cost= 0.030871370
# Epoch no:  56
# Epoch: 0057 cost= 0.030852801
# Epoch no:  57
# Epoch: 0058 cost= 0.030433072
# Epoch no:  58
# Epoch: 0059 cost= 0.030684335
# Epoch no:  59
# Epoch: 0060 cost= 0.030605053
# Epoch no:  60
# Epoch: 0061 cost= 0.030604293
# Epoch no:  61
# Epoch: 0062 cost= 0.030523533
# Epoch no:  62
# Epoch: 0063 cost= 0.030318141
# Epoch no:  63
# Epoch: 0064 cost= 0.030581113
# Epoch no:  64
# Epoch: 0065 cost= 0.030656671
# Epoch no:  65
# Epoch: 0066 cost= 0.030437161
# Epoch no:  66
# Epoch: 0067 cost= 0.030546143
# Epoch no:  67
# Epoch: 0068 cost= 0.030498140
# Epoch no:  68
# Epoch: 0069 cost= 0.030235504
# Epoch no:  69
# Epoch: 0070 cost= 0.030351674
# Epoch no:  70
# Epoch: 0071 cost= 0.030331179
# Epoch no:  71
# Epoch: 0072 cost= 0.030354547
# Epoch no:  72
# Epoch: 0073 cost= 0.030151759
# Epoch no:  73
# Epoch: 0074 cost= 0.030252155
# Epoch no:  74
# Epoch: 0075 cost= 0.030301639
# Epoch no:  75
# Epoch: 0076 cost= 0.030333504
# Epoch no:  76
# Epoch: 0077 cost= 0.030206286
# Epoch no:  77
# Epoch: 0078 cost= 0.030091810
# Epoch no:  78
# Epoch: 0079 cost= 0.030078347
# Epoch no:  79
# Epoch: 0080 cost= 0.029946937
# Epoch no:  80
# Epoch: 0081 cost= 0.030035589
# Epoch no:  81
# Epoch: 0082 cost= 0.029993192
# Epoch no:  82
# Epoch: 0083 cost= 0.029916515
# Epoch no:  83
# Epoch: 0084 cost= 0.030109948
# Epoch no:  84
# Epoch: 0085 cost= 0.029939470
# Epoch no:  85
# Epoch: 0086 cost= 0.029695431
# Epoch no:  86
# Epoch: 0087 cost= 0.029982666
# Epoch no:  87
# Epoch: 0088 cost= 0.029786344
# Epoch no:  88
# Epoch: 0089 cost= 0.029884407
# Epoch no:  89
# Epoch: 0090 cost= 0.029703715
# Epoch no:  90
# Epoch: 0091 cost= 0.029666640
# Epoch no:  91
# Epoch: 0092 cost= 0.029532442
# Epoch no:  92
# Epoch: 0093 cost= 0.029809784
# Epoch no:  93
# Epoch: 0094 cost= 0.029870492
# Epoch no:  94
# Epoch: 0095 cost= 0.029465469
# Epoch no:  95
# Epoch: 0096 cost= 0.029660643
# Epoch no:  96
# Epoch: 0097 cost= 0.029507212
# Epoch no:  97
# Epoch: 0098 cost= 0.029677489
# Epoch no:  98
# Epoch: 0099 cost= 0.029515587
# Epoch no:  99
# Epoch: 0100 cost= 0.029622050
# Epoch no:  100
# Epoch: 0101 cost= 0.029564452
# Epoch no:  101
# Epoch: 0102 cost= 0.029399328
# Epoch no:  102
# Epoch: 0103 cost= 0.029431049
# Epoch no:  103
# Epoch: 0104 cost= 0.029490027
# Epoch no:  104
# Epoch: 0105 cost= 0.029399228
# Epoch no:  105
# Epoch: 0106 cost= 0.029401128
# Epoch no:  106
# Epoch: 0107 cost= 0.029312995
# Epoch no:  107
# Epoch: 0108 cost= 0.029192271
# Epoch no:  108
# Epoch: 0109 cost= 0.029429960
# Epoch no:  109
# Epoch: 0110 cost= 0.029129563
# Epoch no:  110
# Epoch: 0111 cost= 0.029165036
# Epoch no:  111
# Epoch: 0112 cost= 0.029614267
# Epoch no:  112
# Epoch: 0113 cost= 0.029309614
# Epoch no:  113
# Epoch: 0114 cost= 0.029047394
# Epoch no:  114
# Epoch: 0115 cost= 0.029221523
# Epoch no:  115
# Epoch: 0116 cost= 0.029129246
# Epoch no:  116
# Epoch: 0117 cost= 0.029138393
# Epoch no:  117
# Epoch: 0118 cost= 0.029093349
# Epoch no:  118
# Epoch: 0119 cost= 0.029097060
# Epoch no:  119
# Epoch: 0120 cost= 0.029012159
# Epoch no:  120
# Epoch: 0121 cost= 0.028958732
# Epoch no:  121
# Epoch: 0122 cost= 0.029014996
# Epoch no:  122
# Epoch: 0123 cost= 0.028992365
# Epoch no:  123
# Epoch: 0124 cost= 0.029051901
# Epoch no:  124
# Epoch: 0125 cost= 0.028958282
# Epoch no:  125
# Epoch: 0126 cost= 0.028865311
# Epoch no:  126
# Epoch: 0127 cost= 0.029312124
# Epoch no:  127
# Epoch: 0128 cost= 0.028952851
# Epoch no:  128
# Epoch: 0129 cost= 0.028766616
# Epoch no:  129
# Epoch: 0130 cost= 0.029036781
# Epoch no:  130
# Epoch: 0131 cost= 0.029322449
# Epoch no:  131
# Epoch: 0132 cost= 0.028942409
# Epoch no:  132
# Epoch: 0133 cost= 0.028785418
# Epoch no:  133
# Epoch: 0134 cost= 0.028563215
# Epoch no:  134
# Epoch: 0135 cost= 0.028612247
# Epoch no:  135
# Epoch: 0136 cost= 0.028460041
# Epoch no:  136
# Epoch: 0137 cost= 0.028705590
# Epoch no:  137
# Epoch: 0138 cost= 0.028532664
# Epoch no:  138
# Epoch: 0139 cost= 0.028594298
# Epoch no:  139
# Epoch: 0140 cost= 0.029043322
# Epoch no:  140
# Epoch: 0141 cost= 0.028803143
# Epoch no:  141
# Epoch: 0142 cost= 0.028515943
# Epoch no:  142
# Epoch: 0143 cost= 0.028587537
# Epoch no:  143
# Epoch: 0144 cost= 0.028927935
# Epoch no:  144
# Epoch: 0145 cost= 0.028448719
# Epoch no:  145
# Epoch: 0146 cost= 0.028447326
# Epoch no:  146
# Epoch: 0147 cost= 0.028676439
# Epoch no:  147
# Epoch: 0148 cost= 0.028552132
# Epoch no:  148
# Epoch: 0149 cost= 0.028668387
# Epoch no:  149
# Epoch: 0150 cost= 0.028361944
# Epoch no:  150
# Epoch: 0151 cost= 0.028631120
# Epoch no:  151
# Epoch: 0152 cost= 0.028474232
# Epoch no:  152
# Epoch: 0153 cost= 0.028436570
# Epoch no:  153
# Epoch: 0154 cost= 0.028352078
# Epoch no:  154
# Epoch: 0155 cost= 0.028326827
# Epoch no:  155
# Epoch: 0156 cost= 0.028576428
# Epoch no:  156
# Epoch: 0157 cost= 0.028396453
# Epoch no:  157
# Epoch: 0158 cost= 0.028327265
# Epoch no:  158
# Epoch: 0159 cost= 0.028338645
# Epoch no:  159
# Epoch: 0160 cost= 0.028522707
# Epoch no:  160
# Epoch: 0161 cost= 0.028454727
# Epoch no:  161
# Epoch: 0162 cost= 0.028449490
# Epoch no:  162
# Epoch: 0163 cost= 0.028441785
# Epoch no:  163
# Epoch: 0164 cost= 0.028392197
# Epoch no:  164
# Epoch: 0165 cost= 0.028119786
# Epoch no:  165
# Epoch: 0166 cost= 0.028208700
# Epoch no:  166
# Epoch: 0167 cost= 0.028430341
# Epoch no:  167
# Epoch: 0168 cost= 0.028187962
# Epoch no:  168
# Epoch: 0169 cost= 0.028232839
# Epoch no:  169
# Epoch: 0170 cost= 0.028590283
# Epoch no:  170
# Epoch: 0171 cost= 0.028472944
# Epoch no:  171
# Epoch: 0172 cost= 0.028447471
# Epoch no:  172
# Epoch: 0173 cost= 0.028558853
# Epoch no:  173
# Epoch: 0174 cost= 0.028514906
# Epoch no:  174
# Epoch: 0175 cost= 0.028481161
# Epoch no:  175
# Epoch: 0176 cost= 0.028281650
# Epoch no:  176
# Epoch: 0177 cost= 0.028492171
# Epoch no:  177
# Epoch: 0178 cost= 0.028278852
# Epoch no:  178
# Epoch: 0179 cost= 0.028448371
# Epoch no:  179
# Epoch: 0180 cost= 0.029166847
# Epoch no:  180
# Epoch: 0181 cost= 0.028556049
# Epoch no:  181
# Epoch: 0182 cost= 0.028377204
# Epoch no:  182
# Epoch: 0183 cost= 0.028262003
# Epoch no:  183
# Epoch: 0184 cost= 0.028248465
# Epoch no:  184
# Epoch: 0185 cost= 0.028384643
# Epoch no:  185
# Epoch: 0186 cost= 0.028579608
# Epoch no:  186
# Epoch: 0187 cost= 0.028363597
# Epoch no:  187
# Epoch: 0188 cost= 0.028462538
# Epoch no:  188
# Epoch: 0189 cost= 0.028222802
# Epoch no:  189
# Epoch: 0190 cost= 0.028243024
# Epoch no:  190
# Epoch: 0191 cost= 0.028218515
# Epoch no:  191
# Epoch: 0192 cost= 0.028843625
# Epoch no:  192
# Epoch: 0193 cost= 0.028326737
# Epoch no:  193
# Epoch: 0194 cost= 0.028355034
# Epoch no:  194
# Epoch: 0195 cost= 0.028411798
# Epoch no:  195
# Epoch: 0196 cost= 0.028098137
# Epoch no:  196
# Epoch: 0197 cost= 0.028233144
# Epoch no:  197
# Epoch: 0198 cost= 0.028226749
# Epoch no:  198
# Epoch: 0199 cost= 0.027865326
# Epoch no:  199
# Epoch: 0200 cost= 0.028034153
# Epoch no:  200
# Epoch: 0201 cost= 0.028083504
# Epoch no:  201
# Epoch: 0202 cost= 0.028139485
# Epoch no:  202
# Epoch: 0203 cost= 0.028363982
# Epoch no:  203
# Epoch: 0204 cost= 0.028239840
# Epoch no:  204
# Epoch: 0205 cost= 0.028386558
# Epoch no:  205
# Epoch: 0206 cost= 0.028191579
# Epoch no:  206
# Epoch: 0207 cost= 0.028302782
# Epoch no:  207
# Epoch: 0208 cost= 0.028299727
# Epoch no:  208
# Epoch: 0209 cost= 0.028057084
# Epoch no:  209
# Epoch: 0210 cost= 0.028170057
# Epoch no:  210
# Epoch: 0211 cost= 0.028306222
# Epoch no:  211
# Epoch: 0212 cost= 0.028108367
# Epoch no:  212
# Epoch: 0213 cost= 0.027970637
# Epoch no:  213
# Epoch: 0214 cost= 0.027845079
# Epoch no:  214
# Epoch: 0215 cost= 0.027943516
# Epoch no:  215
# Epoch: 0216 cost= 0.028076140
# Epoch no:  216
# Epoch: 0217 cost= 0.027881928
# Epoch no:  217
# Epoch: 0218 cost= 0.028515775
# Epoch no:  218
# Epoch: 0219 cost= 0.027898858
# Epoch no:  219
# Epoch: 0220 cost= 0.028113868
# Epoch no:  220
# Epoch: 0221 cost= 0.027823191
# Epoch no:  221
# Epoch: 0222 cost= 0.027975243
# Epoch no:  222
# Epoch: 0223 cost= 0.027837326
# Epoch no:  223
# Epoch: 0224 cost= 0.027908740
# Epoch no:  224
# Epoch: 0225 cost= 0.028419025
# Epoch no:  225
# Epoch: 0226 cost= 0.028013641
# Epoch no:  226
# Epoch: 0227 cost= 0.027834784
# Epoch no:  227
# Epoch: 0228 cost= 0.027843463
# Epoch no:  228
# Epoch: 0229 cost= 0.027715859
# Epoch no:  229
# Epoch: 0230 cost= 0.027885724
# Epoch no:  230
# Epoch: 0231 cost= 0.027801280
# Epoch no:  231
# Epoch: 0232 cost= 0.027799520
# Epoch no:  232
# Epoch: 0233 cost= 0.027873176
# Epoch no:  233
# Epoch: 0234 cost= 0.027767645
# Epoch no:  234
# Epoch: 0235 cost= 0.028017259
# Epoch no:  235
# Epoch: 0236 cost= 0.028049811
# Epoch no:  236
# Epoch: 0237 cost= 0.027868128
# Epoch no:  237
# Epoch: 0238 cost= 0.027665078
# Epoch no:  238
# Epoch: 0239 cost= 0.027726476
# Epoch no:  239
# Epoch: 0240 cost= 0.027692189
# Epoch no:  240
# Epoch: 0241 cost= 0.027832824
# Epoch no:  241
# Epoch: 0242 cost= 0.027847650
# Epoch no:  242
# Epoch: 0243 cost= 0.027863712
# Epoch no:  243
# Epoch: 0244 cost= 0.027833013
# Epoch no:  244
# Epoch: 0245 cost= 0.028025159
# Epoch no:  245
# Epoch: 0246 cost= 0.027673126
# Epoch no:  246
# Epoch: 0247 cost= 0.027741031
# Epoch no:  247
# Epoch: 0248 cost= 0.027606044
# Epoch no:  248
# Epoch: 0249 cost= 0.027736506
# Epoch no:  249
# Epoch: 0250 cost= 0.027848626
# Epoch no:  250
# Epoch: 0251 cost= 0.028038613
# Epoch no:  251
# Epoch: 0252 cost= 0.027652966
# Epoch no:  252
# Epoch: 0253 cost= 0.028401410
# Epoch no:  253
# Epoch: 0254 cost= 0.028353539
# Epoch no:  254
# Epoch: 0255 cost= 0.027546354
# Epoch no:  255
# Epoch: 0256 cost= 0.027784935
# Epoch no:  256
# Epoch: 0257 cost= 0.027777325
# Epoch no:  257
# Epoch: 0258 cost= 0.027619475
# Epoch no:  258
# Epoch: 0259 cost= 0.027731390
# Epoch no:  259
# Epoch: 0260 cost= 0.028134133
# Epoch no:  260
# Epoch: 0261 cost= 0.027796475
# Epoch no:  261
# Epoch: 0262 cost= 0.027584734
# Epoch no:  262
# Epoch: 0263 cost= 0.027719253
# Epoch no:  263
# Epoch: 0264 cost= 0.027757560
# Epoch no:  264
# Epoch: 0265 cost= 0.027572567
# Epoch no:  265
# Epoch: 0266 cost= 0.028021997
# Epoch no:  266
# Epoch: 0267 cost= 0.027732531
# Epoch no:  267
# Epoch: 0268 cost= 0.027648879
# Epoch no:  268
# Epoch: 0269 cost= 0.027573762
# Epoch no:  269
# Epoch: 0270 cost= 0.027591144
# Epoch no:  270
# Epoch: 0271 cost= 0.027642741
# Epoch no:  271
# Epoch: 0272 cost= 0.027937110
# Epoch no:  272
# Epoch: 0273 cost= 0.027757780
# Epoch no:  273
# Epoch: 0274 cost= 0.027691632
# Epoch no:  274
# Epoch: 0275 cost= 0.029187789
# Epoch no:  275
# Epoch: 0276 cost= 0.028385600
# Epoch no:  276
# Epoch: 0277 cost= 0.027613888
# Epoch no:  277
# Epoch: 0278 cost= 0.027629097
# Epoch no:  278
# Epoch: 0279 cost= 0.027522321
# Epoch no:  279
# Epoch: 0280 cost= 0.027616157
# Epoch no:  280
# Epoch: 0281 cost= 0.027608751
# Epoch no:  281
# Epoch: 0282 cost= 0.027429852
# Epoch no:  282
# Epoch: 0283 cost= 0.027473732
# Epoch no:  283
# Epoch: 0284 cost= 0.027860469
# Epoch no:  284
# Epoch: 0285 cost= 0.027711865
# Epoch no:  285
# Epoch: 0286 cost= 0.028027832
# Epoch no:  286
# Epoch: 0287 cost= 0.028089785
# Epoch no:  287
# Epoch: 0288 cost= 0.027701321
# Epoch no:  288
# Epoch: 0289 cost= 0.027617131
# Epoch no:  289
# Epoch: 0290 cost= 0.027435997
# Epoch no:  290
# Epoch: 0291 cost= 0.027365547
# Epoch no:  291
# Epoch: 0292 cost= 0.027406778
# Epoch no:  292
# Epoch: 0293 cost= 0.027630171
# Epoch no:  293
# Epoch: 0294 cost= 0.027681911
# Epoch no:  294
# Epoch: 0295 cost= 0.027528757
# Epoch no:  295
# Epoch: 0296 cost= 0.027534340
# Epoch no:  296
# Epoch: 0297 cost= 0.027751270
# Epoch no:  297
# Epoch: 0298 cost= 0.027940331
# Epoch no:  298
# Epoch: 0299 cost= 0.027609384
# Epoch no:  299
# Epoch: 0300 cost= 0.027809369
# Epoch no:  300
# Epoch: 0301 cost= 0.027718264
# Epoch no:  301
# Epoch: 0302 cost= 0.027699289
# Epoch no:  302
# Epoch: 0303 cost= 0.027615961
# Epoch no:  303
# Epoch: 0304 cost= 0.027642330
# Epoch no:  304
# Epoch: 0305 cost= 0.027781825
# Epoch no:  305
# Epoch: 0306 cost= 0.027662210
# Epoch no:  306
# Epoch: 0307 cost= 0.028213326
# Epoch no:  307
# Epoch: 0308 cost= 0.027908330
# Epoch no:  308
# Epoch: 0309 cost= 0.028254580
# Epoch no:  309
# Epoch: 0310 cost= 0.027728081
# Epoch no:  310
# Epoch: 0311 cost= 0.027642005
# Epoch no:  311
# Epoch: 0312 cost= 0.027679711
# Epoch no:  312
# Epoch: 0313 cost= 0.027429963
# Epoch no:  313
# Epoch: 0314 cost= 0.027386881
# Epoch no:  314
# Epoch: 0315 cost= 0.027728351
# Epoch no:  315
# Epoch: 0316 cost= 0.027936420
# Epoch no:  316
# Epoch: 0317 cost= 0.027664576
# Epoch no:  317
# Epoch: 0318 cost= 0.027442599
# Epoch no:  318
# Epoch: 0319 cost= 0.027375580
# Epoch no:  319
# Epoch: 0320 cost= 0.027157264
# Epoch no:  320
# Epoch: 0321 cost= 0.027727610
# Epoch no:  321
# Epoch: 0322 cost= 0.027635648
# Epoch no:  322
# Epoch: 0323 cost= 0.027824410
# Epoch no:  323
# Epoch: 0324 cost= 0.027525849
# Epoch no:  324
# Epoch: 0325 cost= 0.027466065
# Epoch no:  325
# Epoch: 0326 cost= 0.027615619
# Epoch no:  326
# Epoch: 0327 cost= 0.027336342
# Epoch no:  327
# Epoch: 0328 cost= 0.027528694
# Epoch no:  328
# Epoch: 0329 cost= 0.027537047
# Epoch no:  329
# Epoch: 0330 cost= 0.027863954
# Epoch no:  330
# Epoch: 0331 cost= 0.028101191
# Epoch no:  331
# Epoch: 0332 cost= 0.028118752
# Epoch no:  332
# Epoch: 0333 cost= 0.027476249
# Epoch no:  333
# Epoch: 0334 cost= 0.027536381
# Epoch no:  334
# Epoch: 0335 cost= 0.027750555
# Epoch no:  335
# Epoch: 0336 cost= 0.027659810
# Epoch no:  336
# Epoch: 0337 cost= 0.027567411
# Epoch no:  337
# Epoch: 0338 cost= 0.027879363
# Epoch no:  338
# Epoch: 0339 cost= 0.027642986
# Epoch no:  339
# Epoch: 0340 cost= 0.027534741
# Epoch no:  340
# Epoch: 0341 cost= 0.027464078
# Epoch no:  341
# Epoch: 0342 cost= 0.027567181
# Epoch no:  342
# Epoch: 0343 cost= 0.027487358
# Epoch no:  343
# Epoch: 0344 cost= 0.027651981
# Epoch no:  344
# Epoch: 0345 cost= 0.027454894
# Epoch no:  345
# Epoch: 0346 cost= 0.027473540
# Epoch no:  346
# Epoch: 0347 cost= 0.027283828
# Epoch no:  347
# Epoch: 0348 cost= 0.027769457
# Epoch no:  348
# Epoch: 0349 cost= 0.027274274
# Epoch no:  349
# Epoch: 0350 cost= 0.027302330
# Epoch no:  350
# Epoch: 0351 cost= 0.028193775
# Epoch no:  351
# Epoch: 0352 cost= 0.027339087
# Epoch no:  352
# Epoch: 0353 cost= 0.027478803
# Epoch no:  353
# Epoch: 0354 cost= 0.027836291
# Epoch no:  354
# Epoch: 0355 cost= 0.028078782
# Epoch no:  355
# Epoch: 0356 cost= 0.028795403
# Epoch no:  356
# Epoch: 0357 cost= 0.027715708
# Epoch no:  357
# Epoch: 0358 cost= 0.027202411
# Epoch no:  358
# Epoch: 0359 cost= 0.027157856
# Epoch no:  359
# Epoch: 0360 cost= 0.027320732
# Epoch no:  360
# Epoch: 0361 cost= 0.027460034
# Epoch no:  361
# Epoch: 0362 cost= 0.027099994
# Epoch no:  362
# Epoch: 0363 cost= 0.027286655
# Epoch no:  363
# Epoch: 0364 cost= 0.027507756
# Epoch no:  364
# Epoch: 0365 cost= 0.027387044
# Epoch no:  365
# Epoch: 0366 cost= 0.027264188
# Epoch no:  366
# Epoch: 0367 cost= 0.028352311
# Epoch no:  367
# Epoch: 0368 cost= 0.027754061
# Epoch no:  368
# Epoch: 0369 cost= 0.027880058
# Epoch no:  369
# Epoch: 0370 cost= 0.027044395
# Epoch no:  370
# Epoch: 0371 cost= 0.027268514
# Epoch no:  371
# Epoch: 0372 cost= 0.027210969
# Epoch no:  372
# Epoch: 0373 cost= 0.027278433
# Epoch no:  373
# Epoch: 0374 cost= 0.027395337
# Epoch no:  374
# Epoch: 0375 cost= 0.027214516
# Epoch no:  375
# Epoch: 0376 cost= 0.027128898
# Epoch no:  376
# Epoch: 0377 cost= 0.027422979
# Epoch no:  377
# Epoch: 0378 cost= 0.027342113
# Epoch no:  378
# Epoch: 0379 cost= 0.027441571
# Epoch no:  379
# Epoch: 0380 cost= 0.027149288
# Epoch no:  380
# Epoch: 0381 cost= 0.027515025
# Epoch no:  381
# Epoch: 0382 cost= 0.028594550
# Epoch no:  382
# Epoch: 0383 cost= 0.028420198
# Epoch no:  383
# Epoch: 0384 cost= 0.027455425
# Epoch no:  384
# Epoch: 0385 cost= 0.027383508
# Epoch no:  385
# Epoch: 0386 cost= 0.027203755
# Epoch no:  386
# Epoch: 0387 cost= 0.027224356
# Epoch no:  387
# Epoch: 0388 cost= 0.027317349
# Epoch no:  388
# Epoch: 0389 cost= 0.027224966
# Epoch no:  389
# Epoch: 0390 cost= 0.027309508
# Epoch no:  390
# Epoch: 0391 cost= 0.027521907
# Epoch no:  391
# Epoch: 0392 cost= 0.027642143
# Epoch no:  392
# Epoch: 0393 cost= 0.027411375
# Epoch no:  393
# Epoch: 0394 cost= 0.027429768
# Epoch no:  394
# Epoch: 0395 cost= 0.027402168
# Epoch no:  395
# Epoch: 0396 cost= 0.027408104
# Epoch no:  396
# Epoch: 0397 cost= 0.027421843
# Epoch no:  397
# Epoch: 0398 cost= 0.027348391
# Epoch no:  398
# Epoch: 0399 cost= 0.027256679
# Epoch no:  399
# Epoch: 0400 cost= 0.028209488
# Epoch no:  400
# Epoch: 0401 cost= 0.027252145
# Epoch no:  401
# Epoch: 0402 cost= 0.027192945
# Epoch no:  402
# Epoch: 0403 cost= 0.027692105
# Epoch no:  403
# Epoch: 0404 cost= 0.027131349
# Epoch no:  404
# Epoch: 0405 cost= 0.027268485
# Epoch no:  405
# Epoch: 0406 cost= 0.027409555
# Epoch no:  406
# Epoch: 0407 cost= 0.027228053
# Epoch no:  407
# Epoch: 0408 cost= 0.027488872
# Epoch no:  408
# Epoch: 0409 cost= 0.027153202
# Epoch no:  409
# Epoch: 0410 cost= 0.027295286
# Epoch no:  410
# Epoch: 0411 cost= 0.027503249
# Epoch no:  411
# Epoch: 0412 cost= 0.027214644
# Epoch no:  412
# Epoch: 0413 cost= 0.027212245
# Epoch no:  413
# Epoch: 0414 cost= 0.027633399
# Epoch no:  414
# Epoch: 0415 cost= 0.027734197
# Epoch no:  415
# Epoch: 0416 cost= 0.027448294
# Epoch no:  416
# Epoch: 0417 cost= 0.029305531
# Epoch no:  417
# Epoch: 0418 cost= 0.028617689
# Epoch no:  418
# Epoch: 0419 cost= 0.027313692
# Epoch no:  419
# Epoch: 0420 cost= 0.026949806
# Epoch no:  420
# Epoch: 0421 cost= 0.027069256
# Epoch no:  421
# Epoch: 0422 cost= 0.027122734
# Epoch no:  422
# Epoch: 0423 cost= 0.026902011
# Epoch no:  423
# Epoch: 0424 cost= 0.027378024
# Epoch no:  424
# Epoch: 0425 cost= 0.027108028
# Epoch no:  425
# Epoch: 0426 cost= 0.027127093
# Epoch no:  426
# Epoch: 0427 cost= 0.027288270
# Epoch no:  427
# Epoch: 0428 cost= 0.026765487
# Epoch no:  428
# Epoch: 0429 cost= 0.027175372
# Epoch no:  429
# Epoch: 0430 cost= 0.027049211
# Epoch no:  430
# Epoch: 0431 cost= 0.027430997
# Epoch no:  431
# Epoch: 0432 cost= 0.027162194
# Epoch no:  432
# Epoch: 0433 cost= 0.026922622
# Epoch no:  433
# Epoch: 0434 cost= 0.027109196
# Epoch no:  434
# Epoch: 0435 cost= 0.027382786
# Epoch no:  435
# Epoch: 0436 cost= 0.026971497
# Epoch no:  436
# Epoch: 0437 cost= 0.028827229
# Epoch no:  437
# Epoch: 0438 cost= 0.027481525
# Epoch no:  438
# Epoch: 0439 cost= 0.026978822
# Epoch no:  439
# Epoch: 0440 cost= 0.026969575
# Epoch no:  440
# Epoch: 0441 cost= 0.027120036
# Epoch no:  441
# Epoch: 0442 cost= 0.027515789
# Epoch no:  442
# Epoch: 0443 cost= 0.026942864
# Epoch no:  443
# Epoch: 0444 cost= 0.027059600
# Epoch no:  444
# Epoch: 0445 cost= 0.027907290
# Epoch no:  445
# Epoch: 0446 cost= 0.027345305
# Epoch no:  446
# Epoch: 0447 cost= 0.026967689
# Epoch no:  447
# Epoch: 0448 cost= 0.027348925
# Epoch no:  448
# Epoch: 0449 cost= 0.027123585
# Epoch no:  449
# Epoch: 0450 cost= 0.027236282
# Epoch no:  450
# Epoch: 0451 cost= 0.027074476
# Epoch no:  451
# Epoch: 0452 cost= 0.026978909
# Epoch no:  452
# Epoch: 0453 cost= 0.027055157
# Epoch no:  453
# Epoch: 0454 cost= 0.027168341
# Epoch no:  454
# Epoch: 0455 cost= 0.027137580
# Epoch no:  455
# Epoch: 0456 cost= 0.027145599
# Epoch no:  456
# Epoch: 0457 cost= 0.027158030
# Epoch no:  457
# Epoch: 0458 cost= 0.027014641
# Epoch no:  458
# Epoch: 0459 cost= 0.027105633
# Epoch no:  459
# Epoch: 0460 cost= 0.027027407
# Epoch no:  460
# Epoch: 0461 cost= 0.026965721
# Epoch no:  461
# Epoch: 0462 cost= 0.026839194
# Epoch no:  462
# Epoch: 0463 cost= 0.028606669
# Epoch: 0464 cost= 0.027121572
# Epoch no:  463
# Epoch: 0465 cost= 0.026982507
# Epoch no:  464
# Epoch: 0466 cost= 0.027477591
# Epoch no:  465
# Epoch: 0467 cost= 0.026767828
# Epoch no:  466
# Epoch: 0468 cost= 0.026768879
# Epoch no:  467
# Epoch: 0469 cost= 0.027307960
# Epoch no:  468
# Epoch: 0470 cost= 0.026919593
# Epoch no:  469
# Epoch: 0471 cost= 0.027128271
# Epoch no:  470
# Epoch: 0472 cost= 0.027758117
# Epoch no:  471
# Epoch: 0473 cost= 0.026982527
# Epoch no:  472
# Epoch: 0474 cost= 0.026654158
# Epoch no:  473
# Epoch: 0475 cost= 0.026843790
# Epoch no:  474
# Epoch: 0476 cost= 0.026792197
# Epoch no:  475
# Epoch: 0477 cost= 0.027062599
# Epoch no:  476
# Epoch: 0478 cost= 0.027032290
# Epoch no:  477
# Epoch: 0479 cost= 0.026955944
# Epoch no:  478
# Epoch: 0480 cost= 0.027372637
# Epoch no:  479
# Epoch: 0481 cost= 0.028332193
# Epoch no:  480
# Epoch: 0482 cost= 0.027744941
# Epoch no:  481
# Epoch: 0483 cost= 0.027139737
# Epoch no:  482
# Epoch: 0484 cost= 0.026794607
# Epoch no:  483
# Epoch: 0485 cost= 0.026832578
# Epoch no:  484
# Epoch: 0486 cost= 0.026799897
# Epoch no:  485
# Epoch: 0487 cost= 0.026840499
# Epoch no:  486
# Epoch: 0488 cost= 0.027230095
# Epoch no:  487
# Epoch: 0489 cost= 0.026946192
# Epoch no:  488
# Epoch: 0490 cost= 0.026880104
# Epoch no:  489
# Epoch: 0491 cost= 0.026820813
# Epoch no:  490
# Epoch: 0492 cost= 0.027081980
# Epoch no:  491
# Epoch: 0493 cost= 0.026948764
# Epoch no:  492
# Epoch: 0494 cost= 0.027120430
# Epoch no:  493
# Epoch: 0495 cost= 0.026767516
# Epoch no:  494
# Epoch: 0496 cost= 0.026812998
# Epoch no:  495
# Epoch: 0497 cost= 0.027402124
# Epoch no:  496
# Epoch: 0498 cost= 0.029562365
# Epoch no:  497
# Epoch: 0499 cost= 0.028279387
# Epoch no:  498
# Epoch: 0500 cost= 0.027460552
# Epoch no:  499
# Epoch: 0501 cost= 0.026969643
# Epoch no:  500
# Epoch: 0502 cost= 0.026853190
# Epoch no:  501
# Epoch: 0503 cost= 0.026933698
# Epoch no:  502
# Epoch: 0504 cost= 0.026769188
# Epoch no:  503
# Epoch: 0505 cost= 0.026751240
# Epoch no:  504
# Epoch: 0506 cost= 0.026872135
# Epoch no:  505
# Epoch: 0507 cost= 0.026971739
# Epoch no:  506
# Epoch: 0508 cost= 0.027052291
# Epoch no:  507
# Epoch: 0509 cost= 0.026816009
# Epoch no:  508
# Epoch: 0510 cost= 0.026808321
# Epoch no:  509
# Epoch: 0511 cost= 0.027534591
# Epoch no:  510
# Epoch: 0512 cost= 0.027204111
# Epoch no:  511
# Epoch: 0513 cost= 0.026813313
# Epoch no:  512
# Epoch: 0514 cost= 0.026826189
# Epoch no:  513
# Epoch: 0515 cost= 0.026521322
# Epoch no:  514
# Epoch: 0516 cost= 0.026958013
# Epoch no:  515
# Epoch: 0517 cost= 0.026993174
# Epoch no:  516
# Epoch: 0518 cost= 0.026850377
# Epoch no:  517
# Epoch: 0519 cost= 0.027003184
# Epoch no:  518
# Epoch: 0520 cost= 0.026814357
# Epoch no:  519
# Epoch: 0521 cost= 0.027027073
# Epoch no:  520
# Epoch: 0522 cost= 0.026891908
# Epoch no:  521
# Epoch: 0523 cost= 0.026662759
# Epoch no:  522
# Epoch: 0524 cost= 0.026963224
# Epoch no:  523
# Epoch: 0525 cost= 0.026731691
# Epoch no:  524
# Epoch: 0526 cost= 0.026726808
# Epoch no:  525
# Epoch: 0527 cost= 0.026873836
# Epoch no:  526
# Epoch: 0528 cost= 0.026966557
# Epoch no:  527
# Epoch: 0529 cost= 0.026821090
# Epoch no:  528
# Epoch: 0530 cost= 0.026571532
# Epoch no:  529
# Epoch: 0531 cost= 0.027120964
# Epoch no:  530
# Epoch: 0532 cost= 0.026791572
# Epoch no:  531
# Epoch: 0533 cost= 0.026870322
# Epoch no:  532
# Epoch: 0534 cost= 0.027272615
# Epoch no:  533
# Epoch: 0535 cost= 0.026726947
# Epoch no:  534
# Epoch: 0536 cost= 0.026965012
# Epoch no:  535
# Epoch: 0537 cost= 0.026779323
# Epoch no:  536
# Epoch: 0538 cost= 0.027113790
# Epoch no:  537
# Epoch: 0539 cost= 0.026915403
# Epoch no:  538
# Epoch: 0540 cost= 0.026737403
# Epoch no:  539
# Epoch: 0541 cost= 0.026536404
# Epoch no:  540
# Epoch: 0542 cost= 0.026698054
# Epoch no:  541
# Epoch: 0543 cost= 0.027613394
# Epoch no:  542
# Epoch: 0544 cost= 0.026633583
# Epoch no:  543
# Epoch: 0545 cost= 0.026707640
# Epoch no:  544
# Epoch: 0546 cost= 0.026597827
# Epoch no:  545
# Epoch: 0547 cost= 0.026434382
# Epoch no:  546
# Epoch: 0548 cost= 0.026592872
# Epoch no:  547
# Epoch: 0549 cost= 0.027554013
# Epoch no:  548
# Epoch: 0550 cost= 0.028377397
# Epoch no:  549
# Epoch: 0551 cost= 0.027268071
# Epoch no:  550
# Epoch: 0552 cost= 0.026792929
# Epoch no:  551
# Epoch: 0553 cost= 0.026686831
# Epoch no:  552
# Epoch: 0554 cost= 0.026857880
# Epoch no:  553
# Epoch: 0555 cost= 0.026722989
# Epoch no:  554
# Epoch: 0556 cost= 0.026583178
# Epoch no:  555
# Epoch: 0557 cost= 0.026806169
# Epoch no:  556
# Epoch: 0558 cost= 0.027049588
# Epoch no:  557
# Epoch: 0559 cost= 0.026821076
# Epoch no:  558
# Epoch: 0560 cost= 0.026925304
# Epoch no:  559
# Epoch: 0561 cost= 0.026543289
# Epoch no:  560
# Epoch: 0562 cost= 0.026514526
# Epoch no:  561
# Epoch: 0563 cost= 0.027426537
# Epoch no:  562
# Epoch: 0564 cost= 0.027138961
# Epoch no:  563
# Epoch: 0565 cost= 0.027225803
# Epoch no:  564
# Epoch: 0566 cost= 0.026918152
# Epoch no:  565
# Epoch: 0567 cost= 0.028347626
# Epoch no:  566
# Epoch: 0568 cost= 0.028137615
# Epoch no:  567
# Epoch: 0569 cost= 0.028061942
# Epoch no:  568
# Epoch: 0570 cost= 0.027752245
# Epoch no:  569
# Epoch: 0571 cost= 0.026790396
# Epoch no:  570
# Epoch: 0572 cost= 0.029052633
# Epoch no:  571
# Epoch: 0573 cost= 0.028331371
# Epoch no:  572
# Epoch: 0574 cost= 0.027672976
# Epoch no:  573
# Epoch: 0575 cost= 0.027431027
# Epoch no:  574
# Epoch: 0576 cost= 0.027071733
# Epoch no:  575
# Epoch: 0577 cost= 0.026855029
# Epoch no:  576
# Epoch: 0578 cost= 0.026539175
# Epoch no:  577
# Epoch: 0579 cost= 0.027105205
# Epoch no:  578
# Epoch: 0580 cost= 0.026762139
# Epoch no:  579
# Epoch: 0581 cost= 0.026649445
# Epoch no:  580
# Epoch: 0582 cost= 0.026785393
# Epoch no:  581
# Epoch: 0583 cost= 0.027008122
# Epoch no:  582
# Epoch: 0584 cost= 0.027358109
# Epoch no:  583
# Epoch: 0585 cost= 0.026982209
# Epoch no:  584
# Epoch: 0586 cost= 0.026671058
# Epoch no:  585
# Epoch: 0587 cost= 0.026879014
# Epoch no:  586
# Epoch: 0588 cost= 0.026789762
# Epoch no:  587
# Epoch: 0589 cost= 0.027913089
# Epoch no:  588
# Epoch: 0590 cost= 0.026909951
# Epoch no:  589
# Epoch: 0591 cost= 0.026847985
# Epoch no:  590
# Epoch: 0592 cost= 0.027225780
# Epoch no:  591
# Epoch: 0593 cost= 0.027294322
# Epoch no:  592
# Epoch: 0594 cost= 0.026829835
# Epoch no:  593
# Epoch: 0595 cost= 0.026564353
# Epoch no:  594
# Epoch: 0596 cost= 0.027142867
# Epoch no:  595
# Epoch: 0597 cost= 0.026521402
# Epoch no:  596
# Epoch: 0598 cost= 0.026696089
# Epoch no:  597
# Epoch: 0599 cost= 0.026376350
# Epoch no:  598
# Epoch: 0600 cost= 0.027838825
# Epoch no:  599
# Epoch: 0601 cost= 0.027572421
# Epoch no:  600
# Epoch: 0602 cost= 0.026590900
# Epoch no:  601
# Epoch: 0603 cost= 0.027364680
# Epoch no:  602
# Epoch: 0604 cost= 0.027009900
# Epoch no:  603
# Epoch: 0605 cost= 0.026610796
# Epoch no:  604
# Epoch: 0606 cost= 0.027308211
# Epoch no:  605
# Epoch: 0607 cost= 0.029673145
# Epoch no:  606
# Epoch: 0608 cost= 0.027288680
# Epoch no:  607
# Epoch: 0609 cost= 0.026724447
# Epoch no:  608
# Epoch: 0610 cost= 0.026602867
# Epoch no:  609
# Epoch: 0611 cost= 0.026442444
# Epoch no:  610
# Epoch: 0612 cost= 0.026800140
# Epoch no:  611
# Epoch: 0613 cost= 0.026579946
# Epoch no:  612
# Epoch: 0614 cost= 0.026331810
# Epoch no:  613
# Epoch: 0615 cost= 0.026537412
# Epoch no:  614
# Epoch: 0616 cost= 0.026261251
# Epoch no:  615
# Epoch: 0617 cost= 0.027395581
# Epoch no:  616
# Epoch: 0618 cost= 0.028776383
# Epoch no:  617
# Epoch: 0619 cost= 0.026915264
# Epoch no:  618
# Epoch: 0620 cost= 0.026668952
# Epoch no:  619
# Epoch: 0621 cost= 0.026230456
# Epoch no:  620
# Epoch: 0622 cost= 0.026700560
# Epoch no:  621
# Epoch: 0623 cost= 0.026327755
# Epoch no:  622
# Epoch: 0624 cost= 0.026505182
# Epoch no:  623
# Epoch: 0625 cost= 0.026730534
# Epoch no:  624
# Epoch: 0626 cost= 0.026721787
# Epoch no:  625
# Epoch: 0627 cost= 0.026725548
# Epoch no:  626
# Epoch: 0628 cost= 0.026828327
# Epoch no:  627
# Epoch: 0629 cost= 0.026811114
# Epoch no:  628
# Epoch: 0630 cost= 0.026431110
# Epoch no:  629
# Epoch: 0631 cost= 0.026537270
# Epoch no:  630
# Epoch: 0632 cost= 0.026714214
# Epoch no:  631
# Epoch: 0633 cost= 0.026877242
# Epoch no:  632
# Epoch: 0634 cost= 0.027656506
# Epoch no:  633
# Epoch: 0635 cost= 0.027273285
# Epoch no:  634
# Epoch: 0636 cost= 0.026659552
# Epoch no:  635
# Epoch: 0637 cost= 0.027042754
# Epoch no:  636
# Epoch: 0638 cost= 0.026716644
# Epoch no:  637
# Epoch: 0639 cost= 0.026881118
# Epoch no:  638
# Epoch: 0640 cost= 0.026580436
# Epoch no:  639
# Epoch: 0641 cost= 0.026482066
# Epoch no:  640
# Epoch: 0642 cost= 0.026624359
# Epoch no:  641
# Epoch: 0643 cost= 0.026603563
# Epoch no:  642
# Epoch: 0644 cost= 0.026830870
# Epoch no:  643
# Epoch: 0645 cost= 0.026599955
# Epoch no:  644
# Epoch: 0646 cost= 0.026374469
# Epoch no:  645
# Epoch: 0647 cost= 0.026943726
# Epoch no:  646
# Epoch: 0648 cost= 0.026654516
# Epoch no:  647
# Epoch: 0649 cost= 0.026432478
# Epoch no:  648
# Epoch: 0650 cost= 0.026724685
# Epoch no:  649
# Epoch: 0651 cost= 0.026707944
# Epoch no:  650
# Epoch: 0652 cost= 0.026680039
# Epoch no:  651
# Epoch: 0653 cost= 0.028174014
# Epoch no:  652
# Epoch: 0654 cost= 0.026813103
# Epoch no:  653
# Epoch: 0655 cost= 0.026616195
# Epoch no:  654
# Epoch: 0656 cost= 0.026614474
# Epoch no:  655
# Epoch: 0657 cost= 0.026701942
# Epoch no:  656
# Epoch: 0658 cost= 0.026746007
# Epoch no:  657
# Epoch: 0659 cost= 0.027238086
# Epoch no:  658
# Epoch: 0660 cost= 0.026726975
# Epoch no:  659
# Epoch: 0661 cost= 0.026454196
# Epoch no:  660
# Epoch: 0662 cost= 0.026669873
# Epoch no:  661
# Epoch: 0663 cost= 0.026744448
# Epoch no:  662
# Epoch: 0664 cost= 0.026460304
# Epoch no:  663
# Epoch: 0665 cost= 0.026343503
# Epoch no:  664
# Epoch: 0666 cost= 0.026738782
# Epoch no:  665
# Epoch: 0667 cost= 0.026906950
# Epoch no:  666
# Epoch: 0668 cost= 0.026575083
# Epoch no:  667
# Epoch: 0669 cost= 0.026942999
# Epoch no:  668
# Epoch: 0670 cost= 0.026784703
# Epoch no:  669
# Epoch: 0671 cost= 0.026357407
# Epoch no:  670
# Epoch: 0672 cost= 0.026981441
# Epoch no:  671
# Epoch: 0673 cost= 0.030869501
# Epoch no:  672
# Epoch: 0674 cost= 0.026947842
# Epoch no:  673
# Epoch: 0675 cost= 0.026679121
# Epoch no:  674
# Epoch: 0676 cost= 0.026478779
# Epoch no:  675
# Epoch: 0677 cost= 0.026537195
# Epoch no:  676
# Epoch: 0678 cost= 0.026461718
# Epoch no:  677
# Epoch: 0679 cost= 0.026376753
# Epoch no:  678
# Epoch: 0680 cost= 0.026471200
# Epoch no:  679
# Epoch: 0681 cost= 0.026480519
# Epoch no:  680
# Epoch: 0682 cost= 0.026644176
# Epoch no:  681
# Epoch: 0683 cost= 0.026338863
# Epoch no:  682
# Epoch: 0684 cost= 0.027222089
# Epoch no:  683
# Epoch: 0685 cost= 0.026909780
# Epoch no:  684
# Epoch: 0686 cost= 0.026575257
# Epoch no:  685
# Epoch: 0687 cost= 0.026674989
# Epoch no:  686
# Epoch: 0688 cost= 0.026646904
# Epoch no:  687
# Epoch: 0689 cost= 0.026648014
# Epoch no:  688
# Epoch: 0690 cost= 0.026318799
# Epoch no:  689
# Epoch: 0691 cost= 0.027484412
# Epoch no:  690
# Epoch: 0692 cost= 0.027169398
# Epoch no:  691
# Epoch: 0693 cost= 0.026337588
# Epoch no:  692
# Epoch: 0694 cost= 0.026340482
# Epoch no:  693
# Epoch: 0695 cost= 0.026371073
# Epoch no:  694
# Epoch: 0696 cost= 0.026741879
# Epoch no:  695
# Epoch: 0697 cost= 0.026805831
# Epoch no:  696
# Epoch: 0698 cost= 0.026725499
# Epoch no:  697
# Epoch: 0699 cost= 0.028772104
# Epoch no:  698
# Epoch: 0700 cost= 0.026958303
# Epoch no:  699
# Epoch: 0701 cost= 0.026596200
# Epoch no:  700
# Epoch: 0702 cost= 0.026833829
# Epoch no:  701
# Epoch: 0703 cost= 0.027470090
# Epoch no:  702
# Epoch: 0704 cost= 0.026642941
# Epoch no:  703
# Epoch: 0705 cost= 0.026549214
# Epoch no:  704
# Epoch: 0706 cost= 0.026304093
# Epoch no:  705
# Epoch: 0707 cost= 0.026149308
# Epoch no:  706
# Epoch: 0708 cost= 0.026451255
# Epoch no:  707
# Epoch: 0709 cost= 0.027021248
# Epoch no:  708
# Epoch: 0710 cost= 0.027210529
# Epoch no:  709
# Epoch: 0711 cost= 0.026574073
# Epoch no:  710
# Epoch: 0712 cost= 0.026282726
# Epoch no:  711
# Epoch: 0713 cost= 0.026608442
# Epoch no:  712
# Epoch: 0714 cost= 0.027092964
# Epoch no:  713
# Epoch: 0715 cost= 0.027037538
# Epoch no:  714
# Epoch: 0716 cost= 0.026576933
# Epoch no:  715
# Epoch: 0717 cost= 0.026658331
# Epoch no:  716
# Epoch: 0718 cost= 0.026509015
# Epoch no:  717
# Epoch: 0719 cost= 0.026553832
# Epoch no:  718
# Epoch: 0720 cost= 0.026341714
# Epoch no:  719
# Epoch: 0721 cost= 0.026507628
# Epoch no:  720
# Epoch: 0722 cost= 0.026714173
# Epoch no:  721
# Epoch: 0723 cost= 0.026441704
# Epoch no:  722
# Epoch: 0724 cost= 0.026361003
# Epoch no:  723
# Epoch: 0725 cost= 0.026379016
# Epoch no:  724
# Epoch: 0726 cost= 0.026657704
# Epoch no:  725
# Epoch: 0727 cost= 0.028411465
# Epoch no:  726
# Epoch: 0728 cost= 0.026798425
# Epoch no:  727
# Epoch: 0729 cost= 0.026251560
# Epoch no:  728
# Epoch: 0730 cost= 0.026464345
# Epoch no:  729
# Epoch: 0731 cost= 0.026213053
# Epoch no:  730
# Epoch: 0732 cost= 0.026477773
# Epoch no:  731
# Epoch: 0733 cost= 0.026482566
# Epoch no:  732
# Epoch: 0734 cost= 0.026296616
# Epoch no:  733
# Epoch: 0735 cost= 0.026949088
# Epoch no:  734
# Epoch: 0736 cost= 0.027075605
# Epoch no:  735
# Epoch: 0737 cost= 0.026506904
# Epoch no:  736
# Epoch: 0738 cost= 0.026591062
# Epoch no:  737
# Epoch: 0739 cost= 0.026142939
# Epoch no:  738
# Epoch: 0740 cost= 0.026655724
# Epoch no:  739
# Epoch: 0741 cost= 0.026221411
# Epoch no:  740
# Epoch: 0742 cost= 0.026827774
# Epoch no:  741
# Epoch: 0743 cost= 0.027184598
# Epoch no:  742
# Epoch: 0744 cost= 0.026603461
# Epoch no:  743
# Epoch: 0745 cost= 0.026466260
# Epoch no:  744
# Epoch: 0746 cost= 0.026468765
# Epoch no:  745
# Epoch: 0747 cost= 0.026787110
# Epoch no:  746
# Epoch: 0748 cost= 0.026506438
# Epoch no:  747
# Epoch: 0749 cost= 0.026530881
# Epoch no:  748
# Epoch: 0750 cost= 0.026458623
# Epoch no:  749
# Epoch: 0751 cost= 0.029466324
# Epoch no:  750
# Epoch: 0752 cost= 0.026935778
# Epoch no:  751
# Epoch: 0753 cost= 0.026344838
# Epoch no:  752
# Epoch: 0754 cost= 0.026141540
# Epoch no:  753
# Epoch: 0755 cost= 0.026591992
# Epoch no:  754
# Epoch: 0756 cost= 0.026890104
# Epoch no:  755
# Epoch: 0757 cost= 0.026226140
# Epoch no:  756
# Epoch: 0758 cost= 0.026423758
# Epoch no:  757
# Epoch: 0759 cost= 0.026812655
# Epoch no:  758
# Epoch: 0760 cost= 0.026808790
# Epoch no:  759
# Epoch: 0761 cost= 0.026272403
# Epoch no:  760
# Epoch: 0762 cost= 0.026468142
# Epoch no:  761
# Epoch: 0763 cost= 0.026587576
# Epoch no:  762
# Epoch: 0764 cost= 0.026310394
# Epoch no:  763
# Epoch: 0765 cost= 0.026433050
# Epoch no:  764
# Epoch: 0766 cost= 0.027353765
# Epoch no:  765
# Epoch: 0767 cost= 0.027142419
# Epoch no:  766
# Epoch: 0768 cost= 0.026566540
# Epoch no:  767
# Epoch: 0769 cost= 0.026384998
# Epoch no:  768
# Epoch: 0770 cost= 0.026554227
# Epoch no:  769
# Epoch: 0771 cost= 0.026211873
# Epoch no:  770
# Epoch: 0772 cost= 0.026252321
# Epoch no:  771
# Epoch: 0773 cost= 0.026578737
# Epoch no:  772
# Epoch: 0774 cost= 0.026667391
# Epoch no:  773
# Epoch: 0775 cost= 0.027228334
# Epoch no:  774
# Epoch: 0776 cost= 0.026794411
# Epoch no:  775
# Epoch: 0777 cost= 0.026414289
# Epoch no:  776
# Epoch: 0778 cost= 0.026377379
# Epoch no:  777
# Epoch: 0779 cost= 0.026300553
# Epoch no:  778
# Epoch: 0780 cost= 0.027243909
# Epoch no:  779
# Epoch: 0781 cost= 0.026677123
# Epoch no:  780
# Epoch: 0782 cost= 0.026726142
# Epoch no:  781
# Epoch: 0783 cost= 0.026201856
# Epoch no:  782
# Epoch: 0784 cost= 0.026748758
# Epoch no:  783
# Epoch: 0785 cost= 0.026410418
# Epoch no:  784
# Epoch: 0786 cost= 0.026477720
# Epoch no:  785
# Epoch: 0787 cost= 0.026171061
# Epoch no:  786
# Epoch: 0788 cost= 0.026582281
# Epoch no:  787
# Epoch: 0789 cost= 0.026422795
# Epoch no:  788
# Epoch: 0790 cost= 0.027346312
# Epoch no:  789
# Epoch: 0791 cost= 0.026646261
# Epoch no:  790
# Epoch: 0792 cost= 0.026872537
# Epoch no:  791
# Epoch: 0793 cost= 0.026294849
# Epoch no:  792
# Epoch: 0794 cost= 0.026555490
# Epoch no:  793
# Epoch: 0795 cost= 0.027759480
# Epoch no:  794
# Epoch: 0796 cost= 0.029795746
# Epoch no:  795
# Epoch: 0797 cost= 0.028290080
# Epoch no:  796
# Epoch: 0798 cost= 0.026505932
# Epoch no:  797
# Epoch: 0799 cost= 0.026119557
# Epoch no:  798
# Epoch: 0800 cost= 0.026295480
# Epoch no:  799
# Epoch: 0801 cost= 0.026423666
# Epoch no:  800
# Epoch: 0802 cost= 0.026741476
# Epoch no:  801
# Epoch: 0803 cost= 0.026497341
# Epoch no:  802
# Epoch: 0804 cost= 0.026630354
# Epoch no:  803
# Epoch: 0805 cost= 0.026674381
# Epoch no:  804
# Epoch: 0806 cost= 0.026600207
# Epoch no:  805
# Epoch: 0807 cost= 0.026399892
# Epoch no:  806
# Epoch: 0808 cost= 0.030449219
# Epoch no:  807
# Epoch: 0809 cost= 0.027307100
# Epoch no:  808
# Epoch: 0810 cost= 0.026920352
# Epoch no:  809
# Epoch: 0811 cost= 0.026236874
# Epoch no:  810
# Epoch: 0812 cost= 0.026308940
# Epoch no:  811
# Epoch: 0813 cost= 0.026321319
# Epoch no:  812
# Epoch: 0814 cost= 0.026562048
# Epoch no:  813
# Epoch: 0815 cost= 0.026304085
# Epoch no:  814
# Epoch: 0816 cost= 0.026399475
# Epoch no:  815
# Epoch: 0817 cost= 0.028159510
# Epoch no:  816
# Epoch: 0818 cost= 0.028189094
# Epoch no:  817
# Epoch: 0819 cost= 0.026724953
# Epoch no:  818
# Epoch: 0820 cost= 0.026283243
# Epoch no:  819
# Epoch: 0821 cost= 0.026553303
# Epoch no:  820
# Epoch: 0822 cost= 0.026731471
# Epoch no:  821
# Epoch: 0823 cost= 0.028145822
# Epoch no:  822
# Epoch: 0824 cost= 0.026333568
# Epoch no:  823
# Epoch: 0825 cost= 0.026628777
# Epoch no:  824
# Epoch: 0826 cost= 0.026400565
# Epoch no:  825
# Epoch: 0827 cost= 0.026621544
# Epoch no:  826
# Epoch: 0828 cost= 0.026720657
# Epoch no:  827
# Epoch: 0829 cost= 0.026632106
# Epoch no:  828
# Epoch: 0830 cost= 0.026460709
# Epoch no:  829
# Epoch: 0831 cost= 0.026362379
# Epoch no:  830
# Epoch: 0832 cost= 0.026427634
# Epoch no:  831
# Epoch: 0833 cost= 0.026433239
# Epoch no:  832
# Epoch: 0834 cost= 0.027255442
# Epoch no:  833
# Epoch: 0835 cost= 0.028898257
# Epoch no:  834
# Epoch: 0836 cost= 0.026770842
# Epoch no:  835
# Epoch: 0837 cost= 0.026652356
# Epoch no:  836
# Epoch: 0838 cost= 0.026637702
# Epoch no:  837
# Epoch: 0839 cost= 0.026408495
# Epoch no:  838
# Epoch: 0840 cost= 0.027629805
# Epoch no:  839
# Epoch: 0841 cost= 0.028349273
# Epoch no:  840
# Epoch: 0842 cost= 0.027109917
# Epoch no:  841
# Epoch: 0843 cost= 0.026309779
# Epoch no:  842
# Epoch: 0844 cost= 0.026331309
# Epoch no:  843
# Epoch: 0845 cost= 0.026074381
# Epoch no:  844
# Epoch: 0846 cost= 0.026293461
# Epoch no:  845
# Epoch: 0847 cost= 0.026503126
# Epoch no:  846
# Epoch: 0848 cost= 0.030157185
# Epoch no:  847
# Epoch: 0849 cost= 0.028106971
# Epoch no:  848
# Epoch: 0850 cost= 0.027192162
# Epoch no:  849
# Epoch: 0851 cost= 0.026785031
# Epoch no:  850
# Epoch: 0852 cost= 0.026592683
# Epoch no:  851
# Epoch: 0853 cost= 0.026581321
# Epoch no:  852
# Epoch: 0854 cost= 0.026257660
# Epoch no:  853
# Epoch: 0855 cost= 0.026596317
# Epoch no:  854
# Epoch: 0856 cost= 0.026490517
# Epoch no:  855
# Epoch: 0857 cost= 0.026520402
# Epoch no:  856
# Epoch: 0858 cost= 0.026462120
# Epoch no:  857
# Epoch: 0859 cost= 0.026914285
# Epoch no:  858
# Epoch: 0860 cost= 0.026667701
# Epoch no:  859
# Epoch: 0861 cost= 0.026519573
# Epoch no:  860
# Epoch: 0862 cost= 0.026841901
# Epoch no:  861
# Epoch: 0863 cost= 0.026393923
# Epoch no:  862
# Epoch: 0864 cost= 0.026364051
# Epoch no:  863
# Epoch: 0865 cost= 0.026211546
# Epoch no:  864
# Epoch: 0866 cost= 0.026815358
# Epoch no:  865
# Epoch: 0867 cost= 0.027322281
# Epoch no:  866
# Epoch: 0868 cost= 0.026635807
# Epoch no:  867
# Epoch: 0869 cost= 0.026715825
# Epoch no:  868
# Epoch: 0870 cost= 0.027949219
# Epoch no:  869
# Epoch: 0871 cost= 0.026737512
# Epoch no:  870
# Epoch: 0872 cost= 0.026441673
# Epoch no:  871
# Epoch: 0873 cost= 0.026731669
# Epoch no:  872
# Epoch: 0874 cost= 0.026559363
# Epoch no:  873
# Epoch: 0875 cost= 0.027024558
# Epoch no:  874
# Epoch: 0876 cost= 0.026794368
# Epoch no:  875
# Epoch: 0877 cost= 0.026708284
# Epoch no:  876
# Epoch: 0878 cost= 0.027075133
# Epoch no:  877
# Epoch: 0879 cost= 0.026584218
# Epoch no:  878
# Epoch: 0880 cost= 0.026634599
# Epoch no:  879
# Epoch: 0881 cost= 0.026675661
# Epoch no:  880
# Epoch: 0882 cost= 0.027074259
# Epoch no:  881
# Epoch: 0883 cost= 0.026778667
# Epoch no:  882
# Epoch: 0884 cost= 0.026301079
# Epoch no:  883
# Epoch: 0885 cost= 0.026261314
# Epoch no:  884
# Epoch: 0886 cost= 0.026688215
# Epoch no:  885
# Epoch: 0887 cost= 0.026525410
# Epoch no:  886
# Epoch: 0888 cost= 0.026304198
# Epoch no:  887
# Epoch: 0889 cost= 0.026280218
# Epoch no:  888
# Epoch: 0890 cost= 0.026803519
# Epoch no:  889
# Epoch: 0891 cost= 0.026557208
# Epoch no:  890
# Epoch: 0892 cost= 0.027157501
# Epoch no:  891
# Epoch: 0893 cost= 0.026883566
# Epoch no:  892
# Epoch: 0894 cost= 0.026421848
# Epoch no:  893
# Epoch: 0895 cost= 0.026721747
# Epoch no:  894
# Epoch: 0896 cost= 0.026126699
# Epoch no:  895
# Epoch: 0897 cost= 0.026311608
# Epoch no:  896
# Epoch: 0898 cost= 0.027213276
# Epoch no:  897
# Epoch: 0899 cost= 0.027317158
# Epoch no:  898
# Epoch: 0900 cost= 0.026575079
# Epoch no:  899
# Epoch: 0901 cost= 0.026221527
# Epoch no:  900
# Epoch: 0902 cost= 0.026778687
# Epoch no:  901
# Epoch: 0903 cost= 0.026898346
# Epoch no:  902
# Epoch: 0904 cost= 0.026400369
# Epoch no:  903
# Epoch: 0905 cost= 0.026680163
# Epoch no:  904
# Epoch: 0906 cost= 0.028117982
# Epoch no:  905
# Epoch: 0907 cost= 0.027983513
# Epoch no:  906
# Epoch: 0908 cost= 0.026976318
# Epoch no:  907
# Epoch: 0909 cost= 0.026636610
# Epoch no:  908
# Epoch: 0910 cost= 0.026325057
# Epoch no:  909
# Epoch: 0911 cost= 0.026492836
# Epoch no:  910
# Epoch: 0912 cost= 0.026300622
# Epoch no:  911
# Epoch: 0913 cost= 0.026492421
# Epoch no:  912
# Epoch: 0914 cost= 0.026574845
# Epoch no:  913
# Epoch: 0915 cost= 0.027174029
# Epoch no:  914
# Epoch: 0916 cost= 0.028288145
# Epoch no:  915
# Epoch: 0917 cost= 0.028383916
# Epoch no:  916
# Epoch: 0918 cost= 0.027041300
# Epoch no:  917
# Epoch: 0919 cost= 0.026451993
# Epoch no:  918
# Epoch: 0920 cost= 0.026124335
# Epoch no:  919
# Epoch: 0921 cost= 0.026195971
# Epoch no:  920
# Epoch: 0922 cost= 0.026171526
# Epoch no:  921
# Epoch: 0923 cost= 0.026379203
# Epoch no:  922
# Epoch: 0924 cost= 0.026258934
# Epoch no:  923
# Epoch: 0925 cost= 0.027046584
# Epoch no:  924
# Epoch: 0926 cost= 0.026566439
# Epoch no:  925
# Epoch: 0927 cost= 0.026886606
# Epoch: 0928 cost= 0.027277696
# Epoch no:  926
# Epoch: 0929 cost= 0.028105619
# Epoch no:  927
# Epoch: 0930 cost= 0.029867649
# Epoch no:  928
# Epoch: 0931 cost= 0.027216872
# Epoch no:  929
# Epoch: 0932 cost= 0.026770833
# Epoch no:  930
# Epoch: 0933 cost= 0.026235069
# Epoch no:  931
# Epoch: 0934 cost= 0.026687687
# Epoch no:  932
# Epoch: 0935 cost= 0.026784264
# Epoch no:  933
# Epoch: 0936 cost= 0.026734035
# Epoch no:  934
# Epoch: 0937 cost= 0.026479333
# Epoch no:  935
# Epoch: 0938 cost= 0.026418435
# Epoch no:  936
# Epoch: 0939 cost= 0.026869930
# Epoch no:  937
# Epoch: 0940 cost= 0.026639231
# Epoch no:  938
# Epoch: 0941 cost= 0.026715757
# Epoch no:  939
# Epoch: 0942 cost= 0.026933483
# Epoch no:  940
# Epoch: 0943 cost= 0.027370125
# Epoch no:  941
# Epoch: 0944 cost= 0.026348027
# Epoch no:  942
# Epoch: 0945 cost= 0.026617165
# Epoch no:  943
# Epoch: 0946 cost= 0.026465564
# Epoch no:  944
# Epoch: 0947 cost= 0.026456014
# Epoch no:  945
# Epoch: 0948 cost= 0.026756588
# Epoch no:  946
# Epoch: 0949 cost= 0.026618304
# Epoch no:  947
# Epoch: 0950 cost= 0.027345521
# Epoch no:  948
# Epoch: 0951 cost= 0.026756684
# Epoch no:  949
# Epoch: 0952 cost= 0.026937260
# Epoch no:  950
# Epoch: 0953 cost= 0.027489126
# Epoch no:  951
# Epoch: 0954 cost= 0.026805597
# Epoch no:  952
# Epoch: 0955 cost= 0.027362837
# Epoch no:  953
# Epoch: 0956 cost= 0.026649470
# Epoch no:  954
# Epoch: 0957 cost= 0.026471745
# Epoch no:  955
# Epoch: 0958 cost= 0.026938410
# Epoch no:  956
# Epoch: 0959 cost= 0.028231391
# Epoch no:  957
# Epoch: 0960 cost= 0.027575204
# Epoch no:  958
# Epoch: 0961 cost= 0.027520649
# Epoch no:  959
# Epoch: 0962 cost= 0.027281208
# Epoch no:  960
# Epoch: 0963 cost= 0.026575390
# Epoch no:  961
# Epoch: 0964 cost= 0.026793918
# Epoch no:  962
# Epoch: 0965 cost= 0.027040118
# Epoch no:  963
# Epoch: 0966 cost= 0.026626529
# Epoch no:  964
# Epoch: 0967 cost= 0.026510618
# Epoch no:  965
# Epoch: 0968 cost= 0.026789152
# Epoch no:  966
# Epoch: 0969 cost= 0.027281171
# Epoch no:  967
# Epoch: 0970 cost= 0.026603368
# Epoch no:  968
# Epoch: 0971 cost= 0.026603333
# Epoch no:  969
# Epoch: 0972 cost= 0.026589335
# Epoch no:  970
# Epoch: 0973 cost= 0.026486254
# Epoch no:  971
# Epoch: 0974 cost= 0.026789670
# Epoch no:  972
# Epoch: 0975 cost= 0.027858131
# Epoch no:  973
# Epoch: 0976 cost= 0.026418100
# Epoch no:  974
# Epoch: 0977 cost= 0.027412454
# Epoch no:  975
# Epoch: 0978 cost= 0.026503344
# Epoch no:  976
# Epoch: 0979 cost= 0.026561639
# Epoch no:  977
# Epoch: 0980 cost= 0.026554364
# Epoch no:  978
# Epoch: 0981 cost= 0.026794742
# Epoch no:  979
# Epoch: 0982 cost= 0.026364458
# Epoch no:  980
# Epoch: 0983 cost= 0.026209059
# Epoch no:  981
# Epoch: 0984 cost= 0.026801760
# Epoch no:  982
# Epoch: 0985 cost= 0.026762914
# Epoch no:  983
# Epoch: 0986 cost= 0.026253270
# Epoch no:  984
# Epoch: 0987 cost= 0.026468165
# Epoch no:  985
# Epoch: 0988 cost= 0.026581718
# Epoch no:  986
# Epoch: 0989 cost= 0.026559541
# Epoch no:  987
# Epoch: 0990 cost= 0.026899322
# Epoch no:  988
# Epoch: 0991 cost= 0.026722792
# Epoch no:  989
# Epoch: 0992 cost= 0.026944607
# Epoch no:  990
# Epoch: 0993 cost= 0.027417418
# Epoch no:  991
# Epoch: 0994 cost= 0.026851125
# Epoch no:  992
# Epoch: 0995 cost= 0.026429203
# Epoch no:  993
# Epoch: 0996 cost= 0.026354372
# Epoch no:  994
# Epoch: 0997 cost= 0.028625076
# Epoch no:  995
# Epoch: 0998 cost= 0.028877966
# Epoch no:  996
# Epoch: 0999 cost= 0.027242520
# Epoch no:  997
# Epoch: 1000 cost= 0.026653862
# Epoch no:  998
# Epoch: 1001 cost= 0.026379378
# Epoch no:  999
# Epoch: 1002 cost= 0.026346785
# Epoch no:  1000
# Epoch: 1003 cost= 0.026295374
# Epoch no:  1001
# Epoch: 1004 cost= 0.026286674
# Epoch no:  1002
# Epoch: 1005 cost= 0.026312077
# Epoch no:  1003
# Epoch: 1006 cost= 0.026337589
# Epoch no:  1004
# Epoch: 1007 cost= 0.027446565
# Epoch no:  1005
# Epoch: 1008 cost= 0.026504325
# Epoch no:  1006
# Epoch: 1009 cost= 0.027600176
# Epoch no:  1007
# Epoch: 1010 cost= 0.027409087
# Epoch no:  1008
# Epoch: 1011 cost= 0.026562802
# Epoch no:  1009
# Epoch: 1012 cost= 0.026477377
# Epoch no:  1010
# Epoch: 1013 cost= 0.026544854
# Epoch no:  1011
# Epoch: 1014 cost= 0.025998399
# Epoch no:  1012
# Epoch: 1015 cost= 0.026305880
# Epoch no:  1013
# Epoch: 1016 cost= 0.030131248
# Epoch no:  1014
# Epoch: 1017 cost= 0.026715609
# Epoch no:  1015
# Epoch: 1018 cost= 0.026992779
# Epoch no:  1016
# Epoch: 1019 cost= 0.026005244
# Epoch no:  1017
# Epoch: 1020 cost= 0.026495712
# Epoch no:  1018
# Epoch: 1021 cost= 0.026115564
# Epoch no:  1019
# Epoch: 1022 cost= 0.026509993
# Epoch no:  1020
# Epoch: 1023 cost= 0.027505727
# Epoch no:  1021
# Epoch: 1024 cost= 0.026515521
# Epoch no:  1022
# Epoch: 1025 cost= 0.026475943
# Epoch no:  1023
# Epoch: 1026 cost= 0.026502958
# Epoch no:  1024
# Epoch: 1027 cost= 0.026633294
# Epoch no:  1025
# Epoch: 1028 cost= 0.027345176
# Epoch no:  1026
# Epoch: 1029 cost= 0.026860971
# Epoch no:  1027
# Epoch: 1030 cost= 0.027865756
# Epoch no:  1028
# Epoch: 1031 cost= 0.026302420
# Epoch no:  1029
# Epoch: 1032 cost= 0.026476292
# Epoch no:  1030
# Epoch: 1033 cost= 0.026283651
# Epoch no:  1031
# Epoch: 1034 cost= 0.026830275
# Epoch no:  1032
# Epoch: 1035 cost= 0.026584863
# Epoch no:  1033
# Epoch: 1036 cost= 0.026718441
# Epoch no:  1034
# Epoch: 1037 cost= 0.027152923
# Epoch no:  1035
# Epoch: 1038 cost= 0.026505411
# Epoch no:  1036
# Epoch: 1039 cost= 0.026482427
# Epoch no:  1037
# Epoch: 1040 cost= 0.027012524
# Epoch no:  1038
# Epoch: 1041 cost= 0.026393039
# Epoch no:  1039
# Epoch: 1042 cost= 0.026336594
# Epoch no:  1040
# Epoch: 1043 cost= 0.026178166
# Epoch no:  1041
# Epoch: 1044 cost= 0.026906190
# Epoch no:  1042
# Epoch: 1045 cost= 0.027742267
# Epoch no:  1043
# Epoch: 1046 cost= 0.026315997
# Epoch no:  1044
# Epoch: 1047 cost= 0.026442168
# Epoch no:  1045
# Epoch: 1048 cost= 0.026468702
# Epoch no:  1046
# Epoch: 1049 cost= 0.027175132
# Epoch no:  1047
# Epoch: 1050 cost= 0.026373332
# Epoch no:  1048
# Epoch: 1051 cost= 0.026301519
# Epoch no:  1049
# Epoch: 1052 cost= 0.026563456
# Epoch no:  1050
# Epoch: 1053 cost= 0.026444767
# Epoch no:  1051
# Epoch: 1054 cost= 0.026896050
# Epoch no:  1052
# Epoch: 1055 cost= 0.029668621
# Epoch no:  1053
# Epoch: 1056 cost= 0.027923404
# Epoch no:  1054
# Epoch: 1057 cost= 0.026310759
# Epoch no:  1055
# Epoch: 1058 cost= 0.026320005
# Epoch no:  1056
# Epoch: 1059 cost= 0.026095262
# Epoch no:  1057
# Epoch: 1060 cost= 0.026456599
# Epoch no:  1058
# Epoch: 1061 cost= 0.026281159
# Epoch no:  1059
# Epoch: 1062 cost= 0.026283177
# Epoch no:  1060
# Epoch: 1063 cost= 0.026424386
# Epoch no:  1061
# Epoch: 1064 cost= 0.026161567
# Epoch no:  1062
# Epoch: 1065 cost= 0.027250115
# Epoch no:  1063
# Epoch: 1066 cost= 0.028894986
# Epoch no:  1064
# Epoch: 1067 cost= 0.027096197
# Epoch no:  1065
# Epoch: 1068 cost= 0.026519750
# Epoch no:  1066
# Epoch: 1069 cost= 0.026520779
# Epoch no:  1067
# Epoch: 1070 cost= 0.026267003
# Epoch no:  1068
# Epoch: 1071 cost= 0.026306852
# Epoch no:  1069
# Epoch: 1072 cost= 0.028616051
# Epoch no:  1070
# Epoch: 1073 cost= 0.027652806
# Epoch no:  1071
# Epoch: 1074 cost= 0.026595240
# Epoch no:  1072
# Epoch: 1075 cost= 0.026448949
# Epoch no:  1073
# Epoch: 1076 cost= 0.026308207
# Epoch no:  1074
# Epoch: 1077 cost= 0.026619277
# Epoch no:  1075
# Epoch: 1078 cost= 0.026505652
# Epoch no:  1076
# Epoch: 1079 cost= 0.026614129
# Epoch no:  1077
# Epoch: 1080 cost= 0.028602327
# Epoch no:  1078
# Epoch: 1081 cost= 0.027786969
# Epoch no:  1079
# Epoch: 1082 cost= 0.026505431
# Epoch no:  1080
# Epoch: 1083 cost= 0.026317998
# Epoch no:  1081
# Epoch: 1084 cost= 0.026389566
# Epoch no:  1082
# Epoch: 1085 cost= 0.026194751
# Epoch no:  1083
# Epoch: 1086 cost= 0.026867428
# Epoch no:  1084
# Epoch: 1087 cost= 0.026254341
# Epoch no:  1085
# Epoch: 1088 cost= 0.026361430
# Epoch no:  1086
# Epoch: 1089 cost= 0.026195128
# Epoch no:  1087
# Epoch: 1090 cost= 0.026658942
# Epoch no:  1088
# Epoch: 1091 cost= 0.026362068
# Epoch no:  1089
# Epoch: 1092 cost= 0.026763721
# Epoch no:  1090
# Epoch: 1093 cost= 0.028399727
# Epoch no:  1091
# Epoch: 1094 cost= 0.026408390
# Epoch no:  1092
# Epoch: 1095 cost= 0.026362439
# Epoch no:  1093
# Epoch: 1096 cost= 0.026228691
# Epoch no:  1094
# Epoch: 1097 cost= 0.026454727
# Epoch no:  1095
# Epoch: 1098 cost= 0.026206496
# Epoch no:  1096
# Epoch: 1099 cost= 0.026846598
# Epoch no:  1097
# Epoch: 1100 cost= 0.026744880
# Epoch no:  1098
# Epoch: 1101 cost= 0.026646302
# Epoch no:  1099
# Epoch: 1102 cost= 0.029213309
# Epoch no:  1100
# Epoch: 1103 cost= 0.029606638
# Epoch no:  1101
# Epoch: 1104 cost= 0.029176546
# Epoch no:  1102
# Epoch: 1105 cost= 0.026605818
# Epoch no:  1103
# Epoch: 1106 cost= 0.026429871
# Epoch no:  1104
# Epoch: 1107 cost= 0.025994451
# Epoch no:  1105
# Epoch: 1108 cost= 0.026168635
# Epoch no:  1106
# Epoch: 1109 cost= 0.026328879
# Epoch no:  1107
# Epoch: 1110 cost= 0.026236717
# Epoch no:  1108
# Epoch: 1111 cost= 0.026126438
# Epoch no:  1109
# Epoch: 1112 cost= 0.026144817
# Epoch no:  1110
# Epoch: 1113 cost= 0.025928123
# Epoch no:  1111
# Epoch: 1114 cost= 0.026367472
# Epoch no:  1112
# Epoch: 1115 cost= 0.026877700
# Epoch no:  1113
# Epoch: 1116 cost= 0.027198367
# Epoch no:  1114
# Epoch: 1117 cost= 0.027391160
# Epoch no:  1115
# Epoch: 1118 cost= 0.026900036
# Epoch no:  1116
# Epoch: 1119 cost= 0.026594565
# Epoch no:  1117
# Epoch: 1120 cost= 0.026554031
# Epoch no:  1118
# Epoch: 1121 cost= 0.026344385
# Epoch no:  1119
# Epoch: 1122 cost= 0.026236429
# Epoch no:  1120
# Epoch: 1123 cost= 0.026521816
# Epoch no:  1121
# Epoch: 1124 cost= 0.026300908
# Epoch no:  1122
# Epoch: 1125 cost= 0.026092126
# Epoch no:  1123
# Epoch: 1126 cost= 0.026198374
# Epoch no:  1124
# Epoch: 1127 cost= 0.026042233
# Epoch no:  1125
# Epoch: 1128 cost= 0.026557774
# Epoch no:  1126
# Epoch: 1129 cost= 0.026370544
# Epoch no:  1127
# Epoch: 1130 cost= 0.027245674
# Epoch no:  1128
# Epoch: 1131 cost= 0.026412837
# Epoch no:  1129
# Epoch: 1132 cost= 0.026367170
# Epoch no:  1130
# Epoch: 1133 cost= 0.026130218
# Epoch no:  1131
# Epoch: 1134 cost= 0.026040485
# Epoch no:  1132
# Epoch: 1135 cost= 0.026265071
# Epoch no:  1133
# Epoch: 1136 cost= 0.026290928
# Epoch no:  1134
# Epoch: 1137 cost= 0.026331818
# Epoch no:  1135
# Epoch: 1138 cost= 0.026697433
# Epoch no:  1136
# Epoch: 1139 cost= 0.026876848
# Epoch no:  1137
# Epoch: 1140 cost= 0.027088210
# Epoch no:  1138
# Epoch: 1141 cost= 0.026451807
# Epoch no:  1139
# Epoch: 1142 cost= 0.027283318
# Epoch no:  1140
# Epoch: 1143 cost= 0.026227116
# Epoch no:  1141
# Epoch: 1144 cost= 0.026345523
# Epoch no:  1142
# Epoch: 1145 cost= 0.026269628
# Epoch no:  1143
# Epoch: 1146 cost= 0.028113301
# Epoch no:  1144
# Epoch: 1147 cost= 0.027883179
# Epoch no:  1145
# Epoch: 1148 cost= 0.026682066
# Epoch no:  1146
# Epoch: 1149 cost= 0.026123293
# Epoch no:  1147
# Epoch: 1150 cost= 0.026178033
# Epoch no:  1148
# Epoch: 1151 cost= 0.026253290
# Epoch no:  1149
# Epoch: 1152 cost= 0.026565404
# Epoch no:  1150
# Epoch: 1153 cost= 0.026193585
# Epoch no:  1151
# Epoch: 1154 cost= 0.026241409
# Epoch no:  1152
# Epoch: 1155 cost= 0.026239738
# Epoch no:  1153
# Epoch: 1156 cost= 0.026419712
# Epoch no:  1154
# Epoch: 1157 cost= 0.026342295
# Epoch no:  1155
# Epoch: 1158 cost= 0.027993984
# Epoch no:  1156
# Epoch: 1159 cost= 0.026832662
# Epoch no:  1157
# Epoch: 1160 cost= 0.026074453
# Epoch no:  1158
# Epoch: 1161 cost= 0.026158105
# Epoch no:  1159
# Epoch: 1162 cost= 0.026671811
# Epoch no:  1160
# Epoch: 1163 cost= 0.026417498
# Epoch no:  1161
# Epoch: 1164 cost= 0.026447921
# Epoch no:  1162
# Epoch: 1165 cost= 0.026250150
# Epoch no:  1163
# Epoch: 1166 cost= 0.026325613
# Epoch no:  1164
# Epoch: 1167 cost= 0.026612639
# Epoch no:  1165
# Epoch: 1168 cost= 0.025886196
# Epoch no:  1166
# Epoch: 1169 cost= 0.028144084
# Epoch no:  1167
# Epoch: 1170 cost= 0.030734980
# Epoch no:  1168
# Epoch: 1171 cost= 0.027544600
# Epoch no:  1169
# Epoch: 1172 cost= 0.026819475
# Epoch no:  1170
# Epoch: 1173 cost= 0.026359818
# Epoch no:  1171
# Epoch: 1174 cost= 0.026178241
# Epoch no:  1172
# Epoch: 1175 cost= 0.026021826
# Epoch no:  1173
# Epoch: 1176 cost= 0.026440033
# Epoch no:  1174
# Epoch: 1177 cost= 0.026167896
# Epoch no:  1175
# Epoch: 1178 cost= 0.026203097
# Epoch no:  1176
# Epoch: 1179 cost= 0.026678858
# Epoch no:  1177
# Epoch: 1180 cost= 0.026541614
# Epoch no:  1178
# Epoch: 1181 cost= 0.026496694
# Epoch no:  1179
# Epoch: 1182 cost= 0.027232722
# Epoch no:  1180
# Epoch: 1183 cost= 0.026914671
# Epoch no:  1181
# Epoch: 1184 cost= 0.026580599
# Epoch no:  1182
# Epoch: 1185 cost= 0.026595968
# Epoch no:  1183
# Epoch: 1186 cost= 0.026261170
# Epoch no:  1184
# Epoch: 1187 cost= 0.026657686
# Epoch no:  1185
# Epoch: 1188 cost= 0.026175221
# Epoch no:  1186
# Epoch: 1189 cost= 0.026597685
# Epoch no:  1187
# Epoch: 1190 cost= 0.026434182
# Epoch no:  1188
# Epoch: 1191 cost= 0.026229979
# Epoch no:  1189
# Epoch: 1192 cost= 0.027108096
# Epoch no:  1190
# Epoch: 1193 cost= 0.027752815
# Epoch no:  1191
# Epoch: 1194 cost= 0.026314221
# Epoch no:  1192
# Epoch: 1195 cost= 0.026947931
# Epoch no:  1193
# Epoch: 1196 cost= 0.026803658
# Epoch no:  1194
# Epoch: 1197 cost= 0.026412162
# Epoch no:  1195
# Epoch: 1198 cost= 0.026083910
# Epoch no:  1196
# Epoch: 1199 cost= 0.026134180
# Epoch no:  1197
# Epoch: 1200 cost= 0.026262726
# Optimization Finished!
# Accuracy: 0.990024
#
# Data Binary Label Statistics
#
# Labels Sample Label-1-Percentage Label-0-Percentage
# ------------- ------------------ ------------------
#         Train      4.86493489668      95.1350651033
#          Test      5.12712550607      94.8728744939
#         Total      4.96981317856      95.0301868214
# Evaluating the model for 3 ML Algorithms
#
# ML Algorithm Prediction Accuracy
# ------------ -------------------
#       KNN-20      0.988145748988
#          SVM      0.989862348178
#   GaussianNB      0.988178137652
